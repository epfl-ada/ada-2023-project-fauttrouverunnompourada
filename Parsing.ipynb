# %% [markdown]
# ## Goal

# %% [markdown]
# The goal of this code is to be able to label characters to first and second roles.
#
#
# This is done as the inputs to predict Critics/Revenue are the movie inputs + 1st role inputs + 2nd role inputs

# %% [markdown]
# 1) Prob: Trop de NaN? Elimine l'acteur principale. Beaucoup manque voir graphe Ali.
#
# *NaN ne peut pas être utiliser mais plus de problème de secondary classé primary (assez de remaining data?)
#
# 2) Prob: Que faire si même valeur? Que faire si 0?
#
# *Egaux si même valeur (pas fait)
#
# *Si 0 ==> Missed (fait)
#
# 3) Prob: Partial_mentions donne des erreurs? Noms de famille?
#
# *Utiliser NLTK et utiliser Mentions_Couns/Partial_counts pour membres de famille (pas fait)
#
# 4) Prob: Nom du character ne figure pas mais plutôt celui de l'acteur?
#
# *Peut rentrer en compte mais arrive pas si souvent (pas fait)
#
# 5) Prob: "Nom" pas pris en compte à cause du manque de "" dans résumé
#
# *Rajouter dans fonction (fait)
#
# 6) Prob: Pas toute la cast dans le dataframe
#
# *Plus de problème (assez de remaining data?)
#
# 7) Prob: Young John vs. John characters
#
# *Garder que le old ou le young pose problème (pas fait)
#
# 8) Autre: Ligne qui se répètent (Dr. Pramila)
#
# *Peut simplement être filter out si pas déjà fait dans le cleaning
#
# 10) Prob: Première mention est le nom du film?
#
# *Eliminer nom du film dans les listes. Titres éponymes donc pas possible de le faire!

# %% [markdown]
# ## Useful libraries

# %%
import pandas as pd
import numpy as np
import ast
import missingno as msno
from geopy.geocoders import Nominatim
import geopandas as gpd
import re
import pycountry_convert as pc
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag import pos_tag
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Home\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Home\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Data importation

# %%
import dataframes as RAW
import cleaning as CLEAN

# %%
RAW.summaries.head()
# Out:
#     Wiki ID                                            Summary
# 0  23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1  31186339  The nation of Panem consists of a wealthy Capi...
# 2  20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3   2231378  The Lemon Drop Kid , a New York City swindler,...
# 4    595909  Seventh-day Adventist Church pastor Michael Ch...

# %%
RAW.character_data.head()
# Out:
#    Wiki ID Freebase ID Release date              Character name   Actor DOB  \
# 0   975900   /m/03vyhn   2001-08-24                    Akooshay  1958-08-26
# 1   975900   /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
# 2   975900   /m/03vyhn   2001-08-24         Desolation Williams  1969-06-15
# 3   975900   /m/03vyhn   2001-08-24          Sgt Jericho Butler  1967-09-12
# 4   975900   /m/03vyhn   2001-08-24             Bashira Kincaid  1977-09-25
#
#   Actor gender  Actor height Actor ethnicity          Actor name  \
# 0            F         1.620             NaN      Wanda De Jesus
# 1            F         1.780      /m/044038p  Natasha Henstridge
# 2            M         1.727         /m/0x67            Ice Cube
# 3            M         1.750             NaN       Jason Statham
# 4            F         1.650             NaN         Clea DuVall
#
#    Actor age at release      Map ID Character ID    Actor ID
# 0                  42.0  /m/0bgchxw   /m/0bgcj3x  /m/03wcfv7
# 1                  27.0   /m/0jys3m   /m/0bgchn4   /m/0346l4
# 2                  32.0   /m/0jys3g   /m/0bgchn_  /m/01vw26l
# 3                  33.0  /m/02vchl6   /m/0bgchnq   /m/034hyc
# 4                  23.0  /m/02vbb3r   /m/0bgchp9   /m/01y9xg

# %%
RAW.movie_data_scraped.head()
# Out:
#     Wiki ID Freebase ID                                         Movie name  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  13696889  /m/03cfc81                                      The Gangsters
# 3  10408933  /m/02qc0j7                           Alexander's Ragtime Band
# 4   6631279   /m/0gffwj                                        Little city
#
#   Release date     Revenue  Runtime  \
# 0   2001-08-24  14010832.0     98.0
# 1   2000-02-16         NaN     95.0
# 2   1913-05-29         NaN     35.0
# 3   1938-08-16   3600000.0    106.0
# 4   1997-04-04         NaN     93.0
#
#                                            Languages  \
# 0                 {"/m/02h40lc": "English Language"}
# 1                 {"/m/02h40lc": "English Language"}
# 2  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 3                 {"/m/02h40lc": "English Language"}
# 4                 {"/m/02h40lc": "English Language"}
#
#                                    Countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2  {"/m/09c7w0": "United States of America"}
# 3  {"/m/09c7w0": "United States of America"}
# 4  {"/m/09c7w0": "United States of America"}
#
#                                               Genres  IMDb rating  Wins  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...          4.9   NaN
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...          6.0   NaN
# 2  {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...          5.9   NaN
# 3  {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...          6.9   1.0
# 4  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...          5.8   NaN
#
#    Nominations
# 0          2.0
# 1          NaN
# 2          NaN
# 3          6.0
# 4          NaN

# %% [markdown]
# ## Data quantities

# %% [markdown]
# Changer RAW.character_data.head() au bon dataframe filtré.
# Besoin de filtre les NaN en character name

# %%
#Add summaries to corresponding characters (can be avoided by using RAW.summaries in functions)
merged = pd.merge(RAW.character_data, RAW.summaries, on='Wiki ID')

# %% [markdown]
# How many characters have NaN for name

# %%
nan_character_name_rows = merged['Character name'].isnull().sum()
nan_character_name_rows
# Out:
# 166069

# %% [markdown]
# How many characters in total

# %%
merged.shape
# Out:
# (308485, 14)

# %% [markdown]
# How many movies with at least one character NaN

# %%
movies_with_nan_character_name = merged[merged['Character name'].isnull()]['Wiki ID'].nunique()
movies_with_nan_character_name
# Out:
# 31882

# %% [markdown]
# How many movies in total

# %%
unique_movies_count = merged['Wiki ID'].nunique()
unique_movies_count
# Out:
# 37779

# %% [markdown]
# ## Parsing

# %% [markdown]
# Take a subset for easier testing. Dropping rows with NaN as Character Name (needed for parsing)

# %%
merged_test = merged.iloc[0:100,:]
merged_test = merged_test.dropna(subset=['Character name'])

# %% [markdown]
# Count mentions (the entire character name has to figure in the summary)

# %%
def count_mentions(summary, character_name):
    return summary.lower().count(character_name.lower())

merged_test['Mentions_Count'] = merged_test.apply(lambda row: count_mentions(row['Summary'], row['Character name']), axis=1)

# %% [markdown]
# Count partial mentions (part of the character name has to figure in the summary)

# %%
def count_partial_mentions(summary, character_name):
    count = 0
    summary_lower = summary.lower()
    character_name_parts = character_name.lower().split()  # Split the character name into parts

    # Count occurrences of each part of the character's name in the summary
    for part in character_name_parts:
        count += summary_lower.count(part)

    return count

merged_test['Partial_Mentions_Count'] = merged_test.apply(lambda row: count_partial_mentions(row['Summary'], row['Character name']), axis=1)

# %% [markdown]
# Keep only the two most partially mentionned and assigns First role to the most mentioned and second role to the other. (USELESS car outdated, il y a bien meilleur maitenant)

# %%
# Group by 'Wiki_ID' and find the top two actors with the most mentions for each movie
top_actors_per_movie = merged_test.groupby('Wiki ID').apply(lambda x: x.nlargest(2, 'Partial_Mentions_Count'))
# Assign roles to the top two actors for each movie
top_actors_per_movie['Role'] = ['First Role', 'Second Role'] * (len(top_actors_per_movie) // 2)
# Drop the groupby index to obtain a flat DataFrame
top_actors_per_movie = top_actors_per_movie.droplevel(0)

# %% [markdown]
# Keeps only the movie with no NaN cast members (USELESS car de toute manière pas toute la cast figure dans le dataframe original)

# %%
# Assuming 'merged' is your DataFrame containing 'Character name', 'Wiki ID', and other columns

# Find rows with NaN in 'Character name'
nan_character_name_rows = merged[merged['Character name'].isnull()]

# Extract unique Wiki IDs from rows with NaN in 'Character name'
nan_character_wiki_ids = nan_character_name_rows['Wiki ID'].unique()

# Filter rows from 'merged' where 'Character name' is not NaN or Wiki ID is not in nan_character_wiki_ids
filtered_merged = merged[(~merged['Character name'].isnull()) | (~merged['Wiki ID'].isin(nan_character_wiki_ids))]

# Now 'filtered_merged' contains rows without NaN in 'Character name' and without rows sharing the same Wiki ID as those with NaN in 'Character name'
filtered_merged_test = filtered_merged.iloc[0:100,:]

# %% [markdown]
# Apply the two counts to filtered_merged_test dataframe

# %%
filtered_merged_test['Mentions_Count'] = filtered_merged_test.apply(lambda row: count_mentions(row['Summary'], row['Character name']), axis=1)
filtered_merged_test['Partial_Mentions_Count'] = filtered_merged_test.apply(lambda row: count_partial_mentions(row['Summary'], row['Character name']), axis=1)
# Out:
# <ipython-input-24-263015d4f1d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_test['Mentions_Count'] = filtered_merged_test.apply(lambda row: count_mentions(row['Summary'], row['Character name']), axis=1)
# <ipython-input-24-263015d4f1d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_test['Partial_Mentions_Count'] = filtered_merged_test.apply(lambda row: count_partial_mentions(row['Summary'], row['Character name']), axis=1)

# %%
# Assuming 'filtered_merged_test' is your DataFrame after filtering

# Group by 'Wiki ID' and find the top two actors with the most mentions for each movie
top_actors_per_movie = filtered_merged_test.groupby('Wiki ID').apply(lambda x: x.nlargest(2, 'Partial_Mentions_Count'))

# Assign roles dynamically based on the number of actors per movie
role_list = ['First Role', 'Second Role'] * (len(top_actors_per_movie) // 2)
if len(top_actors_per_movie) % 2 != 0:
    role_list.append('First Role')  # Adding an extra role for odd-length groups

# Assign roles to the top two actors for each movie
top_actors_per_movie['Role'] = role_list[:len(top_actors_per_movie)]

# Drop the groupby index to obtain a flat DataFrame
top_actors_per_movie = top_actors_per_movie.droplevel(0)

# %%
top_actors_per_movie.head()
# Out:
#      Wiki ID Freebase ID Release date              Character name   Actor DOB  \
# 38    156558   /m/014k4y   2001-06-27                        Jody  1978-12-30
# 37    156558   /m/014k4y   2001-06-27                      Yvette  1970-09-11
# 173   167857   /m/016fyc      1994-10                  Dave Kujan  1952-05-15
# 171   167857   /m/016fyc      1994-10                   Kobayashi  1946-02-07
# 1     975900   /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
#
#     Actor gender  Actor height Actor ethnicity          Actor name  \
# 38             M         1.797         /m/0x67       Tyrese Gibson
# 37             F         1.650         /m/0x67    Taraji P. Henson
# 173            M         1.910        /m/0xnvg    Chazz Palminteri
# 171            M         1.750       /m/02w7gg  Pete Postlethwaite
# 1              F         1.780      /m/044038p  Natasha Henstridge
#
#      Actor age at release      Map ID Character ID    Actor ID  \
# 38                   22.0   /m/0jtx5h   /m/03jnxf4  /m/01l1b90
# 37                   30.0   /m/0jtx5t   /m/03jnxj_   /m/0blbxk
# 173                   NaN  /m/045x9r0   /m/02xhr5m   /m/02t_v1
# 171                   NaN   /m/0k6t7w   /m/02xhr51   /m/018swb
# 1                    27.0   /m/0jys3m   /m/0bgchn4   /m/0346l4
#
#                                                Summary  Mentions_Count  \
# 38   A young 20-year-old named Jody  lives with his...              25
# 37   A young 20-year-old named Jody  lives with his...              22
# 173  On a ship in San Pedro Bay, a faceless figure ...               1
# 171  On a ship in San Pedro Bay, a faceless figure ...               9
# 1    Set in the Tenacious second half of the 22nd c...               0
#
#      Partial_Mentions_Count         Role
# 38                       25   First Role
# 37                       22  Second Role
# 173                      13   First Role
# 171                       9  Second Role
# 1                         9   First Role

# %% [markdown]
# Add movies just for manual verification of results

# %%
# Merge based on the common Wiki ID or Freebase ID
merged_data = pd.merge(top_actors_per_movie, RAW.movie_data_scraped[['Wiki ID', 'Movie name']], on='Wiki ID', how='left')

# %%
merged_data.head()
# Out:
#    Wiki ID Freebase ID Release date              Character name   Actor DOB  \
# 0   156558   /m/014k4y   2001-06-27                        Jody  1978-12-30
# 1   156558   /m/014k4y   2001-06-27                      Yvette  1970-09-11
# 2   167857   /m/016fyc      1994-10                  Dave Kujan  1952-05-15
# 3   167857   /m/016fyc      1994-10                   Kobayashi  1946-02-07
# 4   975900   /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
#
#   Actor gender  Actor height Actor ethnicity          Actor name  \
# 0            M         1.797         /m/0x67       Tyrese Gibson
# 1            F         1.650         /m/0x67    Taraji P. Henson
# 2            M         1.910        /m/0xnvg    Chazz Palminteri
# 3            M         1.750       /m/02w7gg  Pete Postlethwaite
# 4            F         1.780      /m/044038p  Natasha Henstridge
#
#    Actor age at release      Map ID Character ID    Actor ID  \
# 0                  22.0   /m/0jtx5h   /m/03jnxf4  /m/01l1b90
# 1                  30.0   /m/0jtx5t   /m/03jnxj_   /m/0blbxk
# 2                   NaN  /m/045x9r0   /m/02xhr5m   /m/02t_v1
# 3                   NaN   /m/0k6t7w   /m/02xhr51   /m/018swb
# 4                  27.0   /m/0jys3m   /m/0bgchn4   /m/0346l4
#
#                                              Summary  Mentions_Count  \
# 0  A young 20-year-old named Jody  lives with his...              25
# 1  A young 20-year-old named Jody  lives with his...              22
# 2  On a ship in San Pedro Bay, a faceless figure ...               1
# 3  On a ship in San Pedro Bay, a faceless figure ...               9
# 4  Set in the Tenacious second half of the 22nd c...               0
#
#    Partial_Mentions_Count         Role      Movie name
# 0                      25   First Role        Baby Boy
# 1                      22  Second Role        Baby Boy
# 2                      13   First Role             NaN
# 3                       9  Second Role             NaN
# 4                       9   First Role  Ghosts of Mars

# %% [markdown]
# Parsing with NLTK

# %% [markdown]
# Version one of first step: extract character names (unordered (to check))

# %%
# Example movie summaries
summaries = list(RAW.summaries['Summary'].iloc[:200])

# Function to extract character names from a given summary
def extract_character_names(summary):
    characters = {}
    sentences = sent_tokenize(summary)
    
    for sentence in sentences:
        words = word_tokenize(sentence)
        tagged_words = pos_tag(words)
        
        for i in range(len(tagged_words) - 1):
            if tagged_words[i][1] == 'NNP':  # Proper noun (assumed to be a character name)
                name = tagged_words[i][0]
                characters[name] = characters.get(name, 0) + 1
    
    sorted_characters = sorted(characters.items(), key=lambda x: x[1], reverse=True)
    return [char[0] for char in sorted_characters]

# Extract and organize character names from each movie summary
for idx, summary in enumerate(summaries, start=1):
    names = extract_character_names(summary)
    print(f"Movie {idx} character names:")
    print(names)
    print()
# Out:
# Movie 1 character names:
# ['Shlykov', 'Lyosha']
#
# Movie 2 character names:
# ['Katniss', 'Peeta', 'Rue', 'District', 'Haymitch', 'Cato', 'Crane', 'Clove', 'Capitol', 'Hunger', 'Cornucopia', 'President', 'Snow', 'Thresh', 'Panem', 'Reaping', 'Primrose', 'Everdeen', 'Mellark', 'Abernathy', 'Career', 'Caesar', 'Flickerman', 'Games', 'Glimmer', 'Furious', 'Marvel', 'Seneca', 'Gamemaker']
#
# Movie 3 character names:
# ['Induchoodan', 'Menon', 'Manapally', '[', 'Pavithran', 'Indulekha', 'Justice', 'Nambiar', 'Nair', 'Madhavan', 'Anuradha', 'Poovalli', 'Maranchery', 'Karunakara', 'DYSP', 'Sankaranarayanan', 'Indian', 'Civil', 'Service', 'Sudheeran', 'Saikumar', 'Ramakrishnan', 'Moopil', 'Bharathapuzha', 'Aishwarya', 'Mooppil', 'Kerala', 'Kanaka', 'Chandrabhanu', 'Jayakrishnan', 'Poovally', 'Raman', 'Nandagopal', 'Maarar']
#
# Movie 4 character names:
# ['Kid', 'Charley', 'Moran', 'Brainy', 'Nellie', 'Thursday', 'New', 'Santa', 'York', 'Moose', 'Oxford', 'Christmas', 'Claus', 'Lemon', 'Drop', 'City', 'Florida', 'Eve', 'Year', 'Baxter', 'Home', 'Old', 'Dolls', 'Manhattan', 'Nyack', 'Henry']
#
# Movie 5 character names:
# ['Lindy', 'Michael', 'Azaria', 'Chamberlains', 'Adventist', 'Church', 'Chamberlain', 'Outback', 'Seven', 'October', 'Uluru']
# Movie 6 character names:
# ['Thomas', 'Baldwin', 'Kate', 'Stevens', 'Alex', 'Crawford', 'Jack', 'Agent', 'President', 'Secret', 'Service', 'Vaughan', 'Steven']
#
# Movie 7 character names:
# ['Dahlia', 'Cecilia', 'Natasha', 'Veeck', 'Kyle', 'Murray', 'Jersey', 'City', 'Roosevelt', 'Island', 'Mr.', 'Hello', 'Kitty', 'Rimsky', 'Flash', 'Weeks']
#
# Movie 8 character names:
# ['Hannah', 'Dominic', 'Miss', 'Lombardo', 'Leader', 'Sing', 'Jewish', 'Brooklyn', 'Christmas', 'Senior', 'Mickey', 'Dept', 'Education']
#
# Movie 9 character names:
# ['Doe', 'John', 'Mitchell', 'Willoughby', 'Norton', 'Christmas', 'Eve', 'Connell', '[', 'City', 'Hall', 'Ann', 'Henry', 'D.B', 'Edward', 'Arnold', 'Colonel', 'Millsville', 'Hanson', 'Jesus', 'Christ', 'Try']
#
# Movie 10 character names:
# ['Woody', 'Buzz', 'Buzzard']
#
# Movie 11 character names:
# ['Lola', 'Bo', 'Nikki', 'Simona', 'Marco', 'Dotty', 'Victor', 'Texas', 'New', 'Mexico', 'Caucasian', 'Nina']
#
# Movie 12 character names:
# ['Milan', 'Goran', 'Lubos', 'Eman', 'Miluska', 'Frantisek']
#
# Movie 13 character names:
# ['Goon', 'Show', 'Spike', 'Milligan']
#
# Movie 14 character names:
# ['Ari', 'Karen', 'Dov', 'Akiva', 'Kitty', 'Dafna', 'Irgun', 'Gan', 'Taha', 'Palestine', 'Arab', 'Exodus', 'Israel', 'Jews', 'Ben', 'Canaan', 'Zionist', 'Jewish', 'Landau', 'David', 'Jerusalem', 'Acre', 'Nurse', 'Katherine', 'Fremont', 'Karaolos', 'Cyprus', 'Hagannah', 'Brigade', 'Army', 'World', 'War', 'Mandate', 'Famagusta', 'Hansen', 'America', 'Sonderkommando', 'Auschwitz', 'Nazis', 'Barak', 'Agency', 'King', 'Hotel', 'Mount', 'Tabor', 'Prison', 'Abu', 'Yesha', 'Mohammad', 'Amin', 'Grand', 'Mufti', 'Arabs', 'Palmach']
#
# Movie 15 character names:
# ['Kid', 'Play', 'Sydney', 'Shelia', 'Bilal', 'Miles', 'Rick', 'Jamal', 'Dean', 'Mr', 'Lee', 'Landreaux', 'Zora', 'Salena', 'Kramer', 'Stab', 'Zilla', 'Pee', 'Wee', 'Professor', 'Sinclair', 'Pop', 'Foreplay', "N'Play", 'ID', 'N', 'Pajama', 'Pee-Wee', 'A', 'Pops']
#
# Movie 16 character names:
# ['Lucy']
#
# Movie 17 character names:
# ['Colby', 'Lowell', 'Alan', '*', 'Lowells', 'Henrietta', 'Fred', 'Janice', 'Gage', 'Prof.', 'Bowen', 'Mr.', 'Phelps', 'Ulrich']
#
# Movie 18 character names:
# ['Chris', 'Debbie', 'Dream', 'Street', 'Trousdale', 'Biggest', 'Fan']
#
# Movie 19 character names:
# ['Gabriel', '’', 'Ashes', 'Valentino', 'Triad', 'Michael', 'Arabella', 'Laundrymen', 'London', 'Mafia', 'Enrico', 'England', 'Darbeaux', 'Chinese', 'Triads', 'West', 'Simone', 'Tarantola', 'Muhammed', 'Nelson', 'France', 'Tarontola', 'Bound']
#
# Movie 20 character names:
# ['Vietnam', 'Tai', 'United', 'Minh', 'Duc', 'Fall', 'Saigon', 'War', 'Tran', 'Gunnery', 'Sgt', 'Jim', 'Lance', 'Addie', 'Thuy', 'Hoa']
#
# Movie 21 character names:
# ['Bluey', 'Milo', 'Peter', 'Australia', 'Linton', 'Kate', 'Donkin', 'Trent', 'English', 'Squatter', 'Carmody', 'War', 'Division', 'Africa', 'Tobruk', 'Sister', 'Mary', 'New', 'Guinea']
#
# Movie 22 character names:
# ['Red', 'Lumpy', 'Set', 'Eben', 'Bikes']
#
# Movie 23 character names:
# ['Catholic']
#
# Movie 24 character names:
# ['Lucius', 'West', 'Point', 'First', 'Battle', 'Bull', 'Run']
#
# Movie 25 character names:
# ['Zachariah', '’', '–', 'African', 'Zulu', 'Johannesburg', 'Marumu', 'Sophiatown', 'Fearful', 'Vinah', 'Murumu']
#
# Movie 26 character names:
# ['Madhav', 'Sreenu', 'Amrutha', 'Goa', 'Delhi', 'Mumbai', 'Kolkata', 'NRI', 'Holi']
#
# Movie 27 character names:
# ['Bhagwaan', '’', 'Shambu', 'Swaroop', 'Bijli', 'Govinda', '–', 'Dada', 'Madhu', 'Geeta', 'Shantinagar', '”', 'Inspector', 'Vijay', '‘', 'Father', 'Bhopal', 'Disaster', ']', 'Abjectly', 'Hours', 'Bring', 'Deeper']
#
# Movie 28 character names:
# ['Stooges', 'World', 'War', 'II', 'Hilarity']
#
# Movie 29 character names:
# ['Patel', 'Roger', 'Namrata', 'Ritu', 'Ranchhod', 'Rai', 'Gujarati', 'India', 'New', 'York', 'à', 'la', 'Donald', 'Trump', 'THE', 'Kamla', 'Prem', 'Sunder', 'Kapoor']
#
# Movie 30 character names:
# ['Anita', 'Preetam', 'Sita', 'Devi']
#
# Movie 31 character names:
# ['Samson', 'Saran', 'Delilah', 'Ahtur', 'Philistine', 'Semadar', 'Philistines', 'Hebrew', 'Gaza', 'Dannites', 'Nazirite', 'En', 'Dagon', 'Saul', 'Miriam']
#
# Movie 32 character names:
# ['Russian', 'Afghanistan', 'U.S.']
#
# Movie 33 character names:
# ['Mary', 'Portland', 'Oregon', 'Judge']
#
# Movie 34 character names:
# ['Ben', 'Beth', 'Vincent', 'Cappadora', '[', 'Sam', 'Pat', 'Jonathan', 'Jackson', 'Kerry']
#
# Movie 35 character names:
# ['Timmy', 'Kendall', 'Dean', 'Bracken', 'Mary', 'Europe', 'Air', 'Force', 'Boston.BD', 'Horror', 'News', 'DVD', 'Review', 'David', 'Harley', 'Tormented', 'Riggs', 'Picture', 'Purgatory', 'Lt.', 'Sgt', 'Holden']
#
# Movie 36 character names:
# ['Matt', 'Harry', 'Mark', 'Kay', 'Council', 'City', 'Calder', 'Northwestern', 'United', 'Weston', 'Sam', 'Benson', 'Dave', 'Colby']
#
# Movie 37 character names:
# ['Perozzi', 'Mascetti', 'Melandri', 'Titti', 'Necchi', 'Sassaroli', 'Righi', 'Monicelli', 'Amici', 'Florence', 'Count', 'Madonna']
#
# Movie 38 character names:
# ['Porky', 'Daffy', 'Pig', 'Duck', 'Sleepy', 'LaGoon']
#
# Movie 39 character names:
# ['Jason', 'Nebraska', 'Frances']
#
# Movie 40 character names:
# ['Mickey', 'Scorpions']
#
# Movie 41 character names:
# ['Cao', 'Sun', 'Zhuge', 'Yu', 'Liang', 'Zhou', 'Quan', 'Liu', 'Bei', 'Yun', 'Zhang', 'Cai', 'Mao', 'Shangxiang', 'Woo', 'Jiang', 'Province', 'Battle', 'Zhao', 'Red', 'Gan', 'Xiaoqiao', 'Director', 'John', 'David', 'Stratton', 'Han', 'Dynasty', 'Emperor', 'Xian', 'Changban', 'Guan', 'Fei', 'Jiangdong', 'Bagua', 'Formation', 'Cliff.jpg|right|thumb|Sun', 'Lu', 'Su', 'Hou', 'Yong', 'Winter', 'Solstice', 'Hong', 'Jun', 'Mengmeng', 'Cliff', 'English', 'North', 'America', 'Magnolia', 'Entertainment', 'DVD', 'Blu-ray', 'March']
#
# Movie 42 character names:
# ['Bad', 'Weird', 'Good', 'Manchuria', 'Ghost', 'Market', 'Qing', 'Dynasty', 'Imperial', 'Army', 'Empire', 'Finger', 'Chopper', 'Mexican', 'Manchurian']
#
# Movie 43 character names:
# ['Nikolai', 'Semyon', 'Anna', 'Kirill', 'Tatiana', 'Stepan', 'Azim', 'London', 'Thames', 'Chechen', 'Khitrova', 'Mafia', 'Helen', 'KGB', 'Luzhin', 'River', 'UK', 'Chechens', 'FSB', 'Government', 'Officer', 'Edinburgh', 'Christine']
#
# Movie 44 character names:
# ['Betty', 'Boop', 'Bimbo', 'Koko', 'Dancing', 'School', 'Soul']
#
# Movie 45 character names:
# ['Paschalis', 'Sifnos', 'Zoi', 'Anthoula', 'Milos']
#
# Movie 46 character names:
# ['Kishen', 'Prem', 'Bobby', 'Kaajal', 'Shekhar', 'Sanjana', 'Pooja']
#
# Movie 47 character names:
# ['Tahaan', 'Birbal', 'Subhan', 'Zafar', 'Darr', 'Idrees', 'Haba', 'Zoya', 'Kashmir']
#
# Movie 48 character names:
# ['Feldberg', 'Berlin', 'Günther', 'Stobanski', 'Ulmen', 'Internet', 'Jerome', 'Ades', 'Til', 'Schweiger', 'Roland', 'Wotan', 'Wilke', 'Möhring', 'Susanne', 'Nadja', 'Uhl', 'Philip', 'Henrion', 'Maxim', 'Mehmet', 'Niklas', 'Michalke', 'Florian', 'David', 'Fitz', 'Bruce', 'Berger', 'Justus', 'von', 'Dohnányi']
#
# Movie 49 character names:
# ['Dee', 'Honeywagon', 'Potato', 'Bug', 'Bikini', 'Beach', 'Frankie', 'School', 'millionaire', 'Harvey', 'Huntington', 'III', '–', 'Clyde', 'Peter', 'Royce', 'Bentley']
#
# Movie 50 character names:
# ['Conqueror', 'Cloud', 'Wind', 'Lord', 'Mud', 'Buddha', 'Charity', 'Clan']
#
# Movie 51 character names:
# ['Incident', 'Harmon', 'Cobb', 'Baltimore', 'State', 'Maryland']
#
# Movie 52 character names:
# ['Porky', 'Dobbin', 'Hank', 'Mr.', 'Viper', 'Horsefly', 'Snake', 'Mortgage']
#
# Movie 53 character names:
# ['Odile', 'Red', 'Dead', 'Deray', 'Cannes', 'Simon', 'Jérémi', 'Serge', 'Karamazov', 'Patrick', 'Bialès']
#
# Movie 54 character names:
# ['Gustaf', 'Borgstrom', 'Ardell', 'Kendall', 'Donald', 'Dillingham']
#
# Movie 55 character names:
# ['Chester', 'Roderick', 'Fyodor', 'Narcissa', 'Helen', 'Port-Huntley', 'Lady', 'Winnipeg', 'Kent', 'Canada', 'America', 'Great', 'Broadway', 'Prohibition', 'Serbia', 'Swing', 'Low', 'Sweet', 'Chariot', 'Shattered', 'Horrified', 'Teddy']
#
# Movie 56 character names:
# ['Davar']
#
# Movie 57 character names:
# ['Oliver', 'Dodge', 'Donsky', 'Seth', 'Michael', 'Twisted', 'Tierney', 'Twist', 'London', 'Toronto']
#
# Movie 58 character names:
# ['Gordon', 'Carter', 'Brennan', 'Karloff', 'William', 'U.S.', 'Joel', 'John', 'Nieterstein', 'Army', 'Washington', 'D.C.', 'Europe', 'Lieutenant', 'Assistant', 'Secretary', 'War', 'Major', 'Atlantic', 'Ocean', 'Olivia', 'Captain', 'Nicholas', 'Embassy', 'Ambassador', 'Gregory', 'Afterward']
#
# Movie 59 character names:
# ['Mose', 'Mysterious', 'Walsh', 'Caballero', 'Betty', 'Bizarre', 'Quickly', 'Graveyard', 'Jamboree', 'Seamus', 'Mark', 'Screen', 'Novelties', 'Harry', 'Reser', 'Radio', 'All-star', 'Novelty', 'Orchestra']
#
# Movie 60 character names:
# ['Jada', 'Michael', 'Lorenzo', 'Killjoy', 'Baby', 'Boy', 'T-Bone', 'Jamal', 'Monique', 'Ray', 'Kahara', '[', 'Tamara', 'Mask', 'Ice', 'Cream', 'Man', 'Killjoy/Michael', 'Michael/Killjoy', 'Homeless', 'Jackson']
#
# Movie 61 character names:
# ['Quincey', 'Rawdon', 'Miranda', 'Jack', 'Uncle', 'Kimberly', 'Dad', 'Philippe', 'Husband', 'Mommy', 'Portugal', '–', 'Paula', 'Sam', 'Aunt', 'Moms', 'University', 'Frenchman', 'Miranda—finds']
#
# Movie 62 character names:
# ['Bhavana', 'Diya', 'Sonia', 'Raj', 'Mittal', 'Veer', 'Saxena', 'Aryan', 'Kapoor', 'Madhuri', 'Rekha', 'Dimple', 'Lucky', 'Bhai']
#
# Movie 63 character names:
# ['Nirmal', 'Usha', 'Janaki', 'Babu', 'Satyavati', '[', 'Karthik', 'Melancholic', 'Rajagopal']
#
# Movie 64 character names:
# ['Wile', 'Road', 'Runner', 'E.', 'Latin', 'Ad', 'Infinitum', 'Nemesis', 'Ridiculii', 'Beepius-beepius', 'Ross', 'Frisbee', 'E', 'Charlie', 'Chaplin', 'GOODBYE', 'AGAIN', 'ACME', 'Giant', 'Fly', 'Paper', 'HOW', 'DID', 'EVER', 'GET', 'INTO', 'THIS', 'LINE', 'OF', 'WORK', 'Sale', 'Racket', 'GIGANTIC', 'Coyote', 'Okay']
#
# Movie 65 character names:
# ['Michael', 'Ellen', 'Jake', 'Hoagie', 'Brody', 'Sean', 'Thea', 'Amity', 'Carla', '[', 'Margaret', 'Martin', 'Tiffany', 'Christmas', 'Karen', 'Young', 'William', 'Clarence', '–', 'Island']
#
# Movie 66 character names:
# ['Sagar', 'Manu', 'Rosarios', 'Indu', 'Rosario', 'Naina', 'Imran', 'Hari', '[', 'Arati', 'Alias', 'Jacky', 'Chief', 'Minister', 'Kerala', 'Goa', 'Nanthakrishna', 'Suman', 'Sheikh', 'Enraged', 'Dubai']
#
# Movie 67 character names:
# ['Doc', 'Jimmy', 'Bellamy', 'Evelyn', 'Joan', 'Ralph', 'Healer', 'Mickey', 'Rooney']
#
# Movie 68 character names:
# ['Antonio', 'Set', 'Madrid', 'Almeria', 'Teresa', "D'Lugo|titlePrinceton", 'University', 'Press']
#
# Movie 69 character names:
# ['Hasson', 'Constanza', 'Moked', 'Mr.', 'Shamgar', 'Sergio', 'Yaeli', 'Shifra', 'Wasserman', 'Staff', 'Sgt', 'Raphael', 'Jinji', 'Victor', 'Sinai', 'Education', 'Corps', 'Israeli', 'UN', 'Tel', 'Aviv']
#
# Movie 70 character names:
# ['Rachel', 'Jason', 'HIV', 'IV', 'AIDS', 'Sarah']
#
# Movie 71 character names:
# ['Francisco', 'Exorcist']
#
# Movie 72 character names:
# ['Deaf', 'Brown', 'Film', 'France', 'Philibert', 'Mark', 'Festival', 'Cable', 'Car', 'Cinema', 'Feb.', 'University', 'News', 'Service', 'February', 'Archive', 'Cinematheque', 'Land']
#
# Movie 73 character names:
# ['Schmidt', 'Randall', 'Jeannie', 'Ndugu', 'Winnebago', 'Denver', 'Helen', 'Roberta', 'Warren', 'Woodmen', 'World', 'Omaha', 'Nebraska', 'African', 'Plan', 'USA', 'Umbo', 'Adventurer', 'Hertzel', 'Tanzania']
#
# Movie 74 character names:
# ['Bandini', 'Expand', 'Colorado', 'Unemployed', 'Svevo']
#
# Movie 75 character names:
# ['Stephen', 'China', 'McCarger', 'Hester', '[', 'Don', 'Atlantis', 'No', 'Boss', 'Ho', 'Chase', 'Oil', 'Company', 'Adams', 'Oriental', 'Face', 'J.T', 'Siberia', 'Chases', 'Alice', 'Wellman', 'John', 'Eldredge', 'Jean', 'Muir', 'Orient']
#
# Movie 76 character names:
# ['Littlefoot', 'Hyp', 'Valley', 'Great', 'Mutt', 'Mysterious', 'Beyond', 'Nod', 'Cera', 'Hypsilophodon', 'Nodosaurus', 'Muttaburrasaurus', '’', 'Grandpa', 'Sharpteeth', 'Time', 'Giving', '”']
#
# Movie 77 character names:
# ['Fletcher', 'Max', 'Audrey', 'California', '[', 'Claw', 'Miranda', 'Boston', 'Jerry', 'Los', 'Angeles', 'Reede', 'Justin', 'Cooper', 'Samantha', 'Cole', 'Greta', 'Desperate', 'No']
#
# Movie 78 character names:
# ['Charlotte', 'Miriam', 'Mayhew', 'Drew', 'Velma', 'John', 'Jewel', 'Hollis', 'Louisiana', 'Highway', 'Commission', 'Willis', 'Ascension', 'Parish', 'Bayliss', 'Mr.']
#
# Movie 79 character names:
# ['California']
#
# Movie 80 character names:
# ['Kent', 'California', 'Bobbi']
#
# Movie 81 character names:
# ['Jean', 'Malou', 'Diego', 'World', 'War', 'II', 'Raymond', 'Destiny']
#
# Movie 82 character names:
# ['Jones', 'Robeson', "O'Neill", 'Brutus', 'Emperor', 'Smithers', 'Oscar', 'African', 'Baptist', 'American', 'South', 'Civil', 'Pullman', 'Porter', 'Dolly', 'Jeff', 'Undine', 'Caribbean']
#
# Movie 83 character names:
# ['Kharlamov', 'Earth', 'World', 'War', 'USSR', 'Captain', 'Ivan', 'Sergeyevich', 'Moon—but', 'Kharlamov—the', 'NKVD', 'Chile', 'Soviet', 'Far', 'East', 'Polynesia', 'China', 'Red', 'Stuff.http', 'Chilean', 'Natural', 'Antafagasta', 'Moon', 'EVA']
#
# Movie 84 character names:
# ['Murray', 'Carter']
#
# Movie 85 character names:
# ['Randy', 'Evie', '’', 'Rebecca', 'Wendy', 'Evelyn', 'Vicky', 'Frank', 'Ali', 'Lena', 'Dean', 'Regina', 'Roy', 'Range', 'Rover', 'Walt', 'Whitman', 'Leaves', 'Grass', 'Operation', 'Rescue-like', '“', 'God', '”', 'Rita', 'Mae', 'Brown', 'Rubyfruit', 'Jungle', 'Hollywood', 'Maggenti']
#
# Movie 86 character names:
# ['Betty', 'Pudgy', 'Uncle', 'Max']
#
# Movie 87 character names:
# ['Pierre', 'Cybèle', 'Madeleine', 'Christmas', 'Sunday', 'Bernard', 'Gothic']
#
# Movie 88 character names:
# ['China', 'Dragon', 'Herb', 'Chinese', 'kung']
#
# Movie 89 character names:
# ['Karthik', 'Chitra', 'Shiva', 'Mumbai', 'Indian', 'Express', 'Karthikeyan', 'Navi', 'Srikanth', 'Coonoor']
#
# Movie 90 character names:
# ['Joan', 'God', 'English', 'France', 'Carl', 'Theodor', 'Bloomington', 'London', 'Indiana', 'University', 'Press', 'ISBN']
#
# Movie 91 character names:
# ['Abbas', 'Rajveer', 'Nazir', 'Sapna', 'CHAMPION', 'Singh', 'Punjab', 'Mumbai', 'Khan']
#
# Movie 92 character names:
# ['Katherine', 'Mize', 'Sullivan', 'Jack']
#
# Movie 93 character names:
# ['Badki', 'Chutki', 'Rohan', 'Sahay', 'Shivshankar', 'Sabitri', 'Banaras', 'Mumbai', 'Vivaan', 'Vaibhavari', 'Shubhavari', 'Ganges', 'Natasha', 'MBA', 'Matrix', 'Advertising', 'Old', 'Zurich']
#
# Movie 94 character names:
# ['Anton', 'Yegor', 'Svetlana', 'Watch', 'Dark', 'Zavulon', 'Night', 'Others', 'Chalk', 'Moscow', 'Geser', 'Day', 'Light', 'Olga', 'Alisia', 'Fate', 'Kostya', 'Great', 'New', 'Year', 'Gorodetsky', 'Tamerlane', 'Inquisition', 'Treaty', 'Ostankino', 'Tower', 'NO']
#
# Movie 95 character names:
# ['Sophie', 'Nathan', 'Stingo', 'Auschwitz', 'Józef', 'Wanda', 'Gestapo', 'Zawistowski', 'Landau', 'U.S.', 'Resistance', 'Nobel', 'Prize', 'Jan', 'Eva', 'Crematorium', 'Make', 'Bed', 'Emily', 'Dickinson—the', 'American', 'Brooklyn', 'Virginia']
#
# Movie 96 character names:
# ['Claire', 'Jay', 'Los', 'Angeles', 'PVC']
#
# Movie 97 character names:
# ['Sukumaran', 'Murali', '[', 'Satheesan', 'Vasu', 'Pius', 'Thara', 'Chemistry', 'Narain', 'P.', 'Gulf', 'Romeo', 'Kurup', 'Member', 'Legislative', 'Muvattupuzha', 'Professor', 'Iyer', 'Lakshmi', 'Teacher', 'Mumbai', 'MLA', 'Middle', 'East', '.Raziaarrives.Sukumaran']
#
# Movie 98 character names:
# ['Hyun-chae', 'Gustave', 'Caillebette', 'Window', 'Dong-ha', 'Chae-hyun']
#
# Movie 99 character names:
# ['Jubei', 'Shiro', 'Mataemon', 'Munenori', 'Jushin', 'Ocho', 'Musashi', 'Inshun', 'Botaro', 'Yagyu', 'Shosetsu', 'Soiken', 'Soy', 'Nobutsuna', 'Ohina', 'Shimabara', 'Harano', 'Miyamoto', 'Kishu', 'Godaiyu', 'Amakusa', 'Lord', 'Onwei', 'Satan', 'Tokugawa', 'OVA', 'Hell', 'Madonna', "'Tenshi", 'Matsudaira', 'Araki', 'Hosowei', 'Tamiya', 'Yorinobu', 'Yui', 'Edo', 'Devil', 'Ninja', 'Resurrection', 'Japan', 'Rebellion', 'Shirō', 'Yagyū', 'Jūbei', 'Mitsuyoshi', 'Revenge', 'Cant', 'Castle', "'Ocho", 'Sunlight', 'Kanmoiri', 'Christian', 'General', 'Spawn', 'Riot', 'Sagoguichi', 'Somenight', 'Tajima-no-Kami', 'Inside', 'Mori', 'Mary']
#
# Movie 100 character names:
# ['Swansey', 'Marunga', 'Rhodesia', 'Iroquois', 'David', 'Southern', 'Ian', 'Smith', 'American-made', 'South-West', 'Africa', 'Gideon', 'Security', 'Forces', 'South']
#
# Movie 101 character names:
# ['Stowe', 'Callahan', 'Valerie', 'Jimmy', 'Baylor', 'Walter', 'Chad', 'Van', 'Huffel', 'Chief', 'Mark', 'New', 'Orleans', 'Curry', '[', 'Anthony', 'Gabriel', 'Maria', 'Ronson', 'Mac', 'Rossini', 'Serge', 'William', 'Ash', 'Mansen']
#
# Movie 102 character names:
# ['Frank', 'Susan', 'Duane', 'Jean', 'Ivey', 'Harlan', 'DEA', 'Ibuprofen', 'Demerol', 'Police', 'Lance', 'Phelps', 'Chicago', 'France']
#
# Movie 103 character names:
# ['Chinnarasu', '*', 'Sakthivel', 'Gounder', 'Nandini', 'Gowri', 'Hard', 'Ceheemban', 'Sarath', 'Kumar-', 'Chinnarasu/Sakthivel', 'Devayani-', 'Raadhika-', 'Wife', 'Manivannan-', 'Chinnarasus', 'Sidekick', 'Priya', 'Raman-', 'Jai', 'Ganesh', 'Ajay']
#
# Movie 104 character names:
# ['Rebecca', 'Electra', 'Sarfras', 'Simone', 'Harwin', 'Action', 'Star', 'Ian', 'Alison', 'Firefighter', 'Bobby']
#
# Movie 105 character names:
# ['L', 'Maki', 'Near', 'Nikaido', 'Dr.', 'Kujo', 'Thailand', 'Kimiko', 'Ebola', 'FBI', 'Hideaki', 'Suruga', 'US']
#
# Movie 106 character names:
# ['Ivan', 'Maria', 'Al', 'Clarence', 'Mrs', 'Wynic', 'World', 'War', 'II', 'Pennsylvania', 'Yugoslavia', 'Deeply', 'Furious']
#
# Movie 107 character names:
# ['Pepito', 'Rosa']
#
# Movie 108 character names:
# ['Martin', 'Stannard', '[', 'George', 'Handcuffed', 'Jack', 'Warner', 'Willie', 'Cole', 'Nora', 'Lawrence', 'London']
#
# Movie 109 character names:
# ['William', 'Omer', 'Dreamz', 'President', 'Martin', 'Sally', 'Iqbal', 'Staff', 'Kendoo', 'Williams', 'U.S.', 'US', 'Joseph', 'Staton', 'Idol', 'America', 'American', 'Tweed', '[', 'Chris', 'Klein', 'Obeidi', 'Middle', 'East', 'Southern', 'California', 'Shazzy', 'Iraq', 'Broadway', 'Grease', 'Chief']
#
# Movie 110 character names:
# ['Muthu', 'Veerasamy', '[', 'Meena', 'Kumar', 'Prabhu', 'Kasthuri', 'Ponni', 'Chithra', 'Hopeless', 'Thaali']
#
# Movie 111 character names:
# ['Azoulay', 'Officer', 'Avraham', 'Tel-Aviv', 'Jaffa', 'Captain', 'Levkovich', 'First', 'Sergeant', 'Bejerano', 'Mimi', 'Kohen', 'Halakha', 'French-speaking', 'Arabic', 'Amar', 'Israeli']
#
# Movie 112 character names:
# ['Anthony', 'Rose']
#
# Movie 113 character names:
# ['Johnny', 'Torino', 'Anthony', 'Elizabeth', '[', 'Graham', 'D.A', 'Jones', 'Grace', 'Johnston', 'DA', 'Federal', 'Witness', 'Security', 'Program', 'Vince']
#
# Movie 114 character names:
# ['Deepak', 'Shyam']
#
# Movie 115 character names:
# ['Wolf', 'House', 'Three', 'Little', 'Bops', 'Big', 'Bad', 'Dew', 'Drop', 'Inn', 'Bricks', 'Pigs', 'Straw', 'Sticks', 'No', 'Wolves', 'Allowed', 'Charleston', 'Onward', 'Christian', 'Soldiers', 'TNT', 'Heaven', 'Hell', 'Plus', 'One']
#
# Movie 116 character names:
# ['Ducatel', 'Vandervoorde', 'January', 'Courquain', 'France', 'Koorkin', 'Belgium', 'Ruben', 'Vandevoorde', 'Mathias', 'Louise']
#
# Movie 117 character names:
# ['Emilio', 'Roccanera', 'Black', 'Corsair', 'Governor', 'Van', 'Guld']
#
# Movie 118 character names:
# ['Vishwanathan', 'George', 'Kutty', '[', 'Kochi', 'Mukesh', 'Ambili', 'Mohandas', 'MD', 'VIshwanathan', 'Vishwanathn', 'Vishwanthan', 'Jayaram']
#
# Movie 119 character names:
# ['Edward', 'Mercer', 'Venice', 'Allied', 'World', 'War', 'Italy']
#
# Movie 120 character names:
# ['Vinod', 'Santhosh', 'Kochumon', 'Mahesh', 'Govindapuram', 'Kuttanad', 'Kalyani', 'Son', 'MP', 'Aiswarya', '’', 'Chenkal', 'Choola', 'Babu', 'Caught']
#
# Movie 121 character names:
# ['Ha-sun', 'Heo', 'Gyun', 'Gwang-hae', '’', 'Korea', 'Joseon', 'Dynasty', 'King', 'Park', 'Chung-seo']
#
# Movie 122 character names:
# ['Carlos']
#
# Movie 123 character names:
# ['Dick', 'Gus', 'Morton', 'Jonas', 'Mr.', 'Grooch', 'Creepy', 'Jarvis']
#
# Movie 124 character names:
# ['Jerry', 'Falk', 'New', 'York', 'City', 'Amanda', '’']
#
# Movie 125 character names:
# ['Peter', 'Jimmy', 'Hook', 'Tinker', 'Bell', 'Bonny', 'Aaya', 'Fludd', 'Fox', 'Neverland', 'London', 'Pan', 'James', 'Captain', 'Elizabeth', 'Kaw', 'Native', 'Aaya/Tiger', 'Lily', 'Dr.', 'Queen', 'Earth', 'Utopia', 'England', 'Halfway', 'Natives', 'Original']
#
# Movie 126 character names:
# ['Mary', 'Kelly', 'Max', 'Ginsberg', 'Nathan', 'Burke', 'Tim', '—', 'Riley', 'Mrs.', 'Clothes']
#
# Movie 127 character names:
# ['Hollywood', 'Gun', 'Boats', 'Alas', 'Mysteeryus', 'Mystery', 'Buckwheat', '<', '|', 'Gelder']
#
# Movie 128 character names:
# ['Ross', 'Stacey', 'Hanley', 'Polecat', 'Governor', 'Frank', 'D.A.', 'Jesse', 'Banton', 'Construction', 'Co.', 'Patterson', 'Limpy', 'Grayce', 'Parole', 'Board', 'Joyce', 'National', 'Guard']
#
# Movie 129 character names:
# ['Mountview', 'California', 'General', 'George', 'S.', 'Merlin']
#
# Movie 130 character names:
# ['Olivia', 'Viola', 'Cesario', 'Sir', 'Orsino', 'Toby', 'Andrew', 'Sebastian', 'Illyria', 'Duke', 'Malvolio', 'Feste', 'Aguecheek', 'Antonio', 'Maria', 'Belch', 'Wind', 'Rain']
#
# Movie 131 character names:
# ['Dr.', 'Joyce', 'Snyder', 'McBride', 'Norris', 'Van', 'Gelder', 'Collins', 'Laidlaw', 'Richardson', 'DeepStar', 'Scarpelli', 'Six', 'Navy', 'Osborne', 'Hodges', 'Captain', 'Cpt']
#
# Movie 132 character names:
# ['Part', 'Miles', 'Ago', 'Husband', 'Child', 'Priest', 'Family', 'Man']
#
# Movie 133 character names:
# ['Graham', 'Roy', 'Barnes', 'National', 'Sheriff', 'Rose', 'Deputy', 'Weinman', 'Guard', 'Hundt', 'Sergeant', 'Winshiser', 'Trail', 'Grady', 'Satterly', 'Bengal', 'Sharon', 'Six', 'Guardsmen', 'Colonel', 'James', 'Livingston-Graham', 'England', 'Ezra', 'India']
#
# Movie 134 character names:
# ['Carlos', 'Julio', 'Miguel', 'Don', 'Rosario', 'Carlitos', 'Montero', 'Mistral', 'Mexico', 'Brazil']
#
# Movie 135 character names:
# ['Ben', 'Jones', 'Marion', "'Howdy", 'Lewis', 'Jim', 'Ed', 'Love', 'Mary', 'Sister', 'Howdy']
#
# Movie 136 character names:
# ['Daria', 'Andrew', 'Europe', 'Moscow']
#
# Movie 137 character names:
# ['Tom', 'Los', 'Angeles', 'Eloise', 'FBI']
#
# Movie 138 character names:
# ['*', 'J', '–', 'Shaggy', 'Cast', 'Violent', 'Dope', 'Krista', 'Kalmus', 'Amy', 'Lindsay', 'Ballew', 'Stacy', 'Kathlyne', 'Pham', 'Tiffany', 'Damian', 'Lea', 'Brad', 'Sabin', 'Rich', 'Carl', 'Mark', 'Jury', 'Guy', 'Car', 'Roxxi', 'Dolt', 'Girl']
#
# Movie 139 character names:
# ['Jane']
#
# Movie 140 character names:
# ['Raju', 'Prem', 'Neetu', 'Singh', 'Prince', 'Rajeshwar', 'Queen', 'Thakur', 'Raigadh', 'Juhu', 'Raj', 'Bombay', 'Hindus', 'Khan', 'Muslims', 'Rs.10000', 'Matha', 'Mata', 'Rajmata', 'Dr.', 'Muthuswamy', 'Madras', 'AB']
#
# Movie 141 character names:
# ['Jordan', 'Hunter', 'Wolfsberg', 'Dragomir', 'Varcolac', 'David', 'Paulina', 'Sands', 'Beast', 'Manor', 'Uncle', '’', 'Goran', 'Ashley', 'Tiffany', 'Madame', 'LB-217', 'Edwards', 'Ducovic', 'Romania', 'Moonlight', 'Mania', 'Von', 'Eckberg', 'Greek', 'Lycaon', 'U.S.', 'Baby', 'One']
#
# Movie 142 character names:
# ['Radha', 'Sukhilala', 'Birju', 'Shamu', 'Ramu', "'mother", 'Whilst', 'Though']
#
# Movie 143 character names:
# ['Dr.', 'Allen', 'Tom', 'Mansquito', 'Ray', 'Jennifer', 'Baltimore', 'Maryland', 'Gillian', 'West', 'Nile', 'Lt.', 'Randall', 'Outside']
#
# Movie 144 character names:
# ['Neruda', 'Mario', 'Beatrice', 'Chilean', 'Chile', 'Pablo', 'Italy', 'Ruoppolo', 'Russo', 'Di', 'Cosimo', 'Pablito', 'Naples']
#
# Movie 145 character names:
# ['New', 'Orleans', 'Jazz', 'Baptist', 'Funerals', 'Danny', 'Barker', 'Darren', 'Hoffman', '“']
#
# Movie 146 character names:
# ['Killer']
#
# Movie 147 character names:
# ['Christmas', 'Dana', 'Dan', '[', 'Caribbean', 'Chris', 'Michael', 'Colin', 'Ferguson', 'Blair', 'Nell', 'Puerto', 'Rico', 'Brady', 'Bunch']
#
# Movie 148 character names:
# ['Love', 'Director', 'Sean', 'Cain']
#
# Movie 149 character names:
# ['Hawk', 'Chovinski']
#
# Movie 150 character names:
# ['Betty', 'Zorg', 'Bob', '“', '’']
#
# Movie 151 character names:
# ['Hargan', 'Stooges', 'Skin', 'Flint', 'Finance', 'Corporation', 'Terry', 'Slippery', 'Fingers']
#
# Movie 152 character names:
# ['England', 'Tod', 'Slaughter', 'Sir', 'Percival', 'Glyde', 'Australia', 'Count', 'Fosco', 'Lord', 'Manor']
#
# Movie 153 character names:
# ['Wayne', 'Mighty', 'Lena', 'Bra', 'Johnny', 'B', 'Boey', 'Sabrina', 'Baby-Phobia']
#
# Movie 154 character names:
# ['Zandy', 'Hannah', 'Allan', 'West', 'Minneapolis', 'Lund', 'Maria', 'San', 'Francisco']
#
# Movie 155 character names:
# ['’', 'Mithun', 'Film', 'Chakraborty', 'Rati', 'Dimple', 'Anand', 'Phir', 'Tinnu', 'Agnihotri', 'Gidvani', 'Kapadia', 'Kabhi', 'Love', 'New', 'Light', 'Sound', 'Nataraja', 'Subramanian', 'Mahesh', 'Narayan', 'Person', 'Death', 'Loneliness', 'Kitu', 'Plot', 'Radha', 'Krishna', 'Gulshan', 'Grover', 'Kittu', 'Lambretta', 'CIA', 'Rimoh', 'Nishan', 'Naram', 'Ganga', 'Laxmi', 'ke', 'Tum', '…', 'tum', 'Dev/Vijay', 'Guide', 'Aaj', 'Shahrukh', 'Shantanu', 'Moitra', 'Bhupendra']
#
# Movie 156 character names:
# ['Rod', 'Jessica', '’', 'Valdemar', 'Robert', 'Annabel', 'Mr.', 'Pike', 'Ernest', 'Pittsburgh', 'Detective', 'Grogan', 'Pym', 'Christian', 'LeGrand', 'Case', 'M.', 'Steven', 'Dr.', 'Hoffman', 'Others', 'Black', 'Cat', 'Usher', 'LeGrand-', 'Metropolitan', 'Horrors', 'Medieval', 'Pagan', 'Eleanora', 'Betty', 'Mrs.', 'New', 'York']
#
# Movie 157 character names:
# ['Camille', 'Madame', 'Devries', 'Jean-Baptiste', 'Tanh', 'France', 'Guy', 'Indochina', 'Vietnam', 'South', 'Navy', 'Haiphong', 'Dragon', 'Island', 'Gulf', 'Tonkin', 'Communist', 'North', 'Geneva', 'Nguyen', 'Dynasty', 'Le', 'Guen', 'Christmas', 'China', 'Etienne', 'Saigon', 'Popular', 'Front', 'Étienne', 'Conference']
#
# Movie 158 character names:
# ['Joe', 'Johnson', 'Tom', 'Christian']
#
# Movie 159 character names:
# ['Caesar', 'Marcus', 'Pendleton', 'Smith', 'Amazon', 'Rainforest', 'Europe', 'Patty']
#
# Movie 160 character names:
# ['Morgan', 'Tyree', 'Kiefer', '[', 'Bob', 'Ranch', 'Sonora', 'Mexico', 'Kane', 'Barry', 'Sullivan', 'Kashtok', 'Pike']
#
# Movie 161 character names:
# ['Horton', 'Jane', 'Nool', 'Whoville', 'Mayor', 'JoJo', 'Jungle', 'Vlad', 'Ned', 'McDodd', 'Sally', 'Dr.', 'LaRue', 'Mt', 'Wickersham', 'Vladikoff', 'NOOO', 'Rudy', 'Ca', 'Earth']
#
# Movie 162 character names:
# ['Laurence', 'Fishburne', 'Socrates', 'Fortlow']
#
# Movie 163 character names:
# ['Katka', 'Girl', 'Seven', 'Princess']
#
# Movie 164 character names:
# ['Baggs', 'Maggie', 'Doug', 'Navy', 'Peacetime', 'John', 'J.', 'U.S.', 'Forshay']
#
# Movie 165 character names:
# ['Dan', 'McNab', 'Dierdre', 'Farrel', 'Van', 'Dieman', 'Land', 'Mary', 'Donald', 'Cameron']
#
# Movie 166 character names:
# ['Kang-do']
#
# Movie 167 character names:
# ['Jon', 'Arlene', 'Harry', 'Audrey', 'Aldrich', 'Alrdich', 'Aldrich/Pop', 'Mildred', 'John', 'McDonalds', 'McDonnell', 'Douglas']
#
# Movie 168 character names:
# ['Computer', 'Raymond', 'Kurzweil', 'Hiroshi', 'Ishiguro', 'Joseph', 'Weizenbaum', 'Japan', 'USA', 'Italy', 'Germany']
#
# Movie 169 character names:
# ['Nate', 'Meg', 'Baltimore', 'Max', 'Burns', 'Yukon', 'Homicide', 'Galligan', 'Charlene', 'Alberta', 'Dawson', 'City', 'Territory', 'Klondike', 'Rivers']
#
# Movie 170 character names:
# ['Cruchot', 'Josepha']
#
# Movie 171 character names:
# ['Terr', 'Oms', 'Draag', 'Draags', 'Tiva', 'Om', 'Sinh', 'Wizard', 'Mighty', 'Council', 'Fantastic', 'Planet', 'Aedile', 'Councilors', 'One', 'Afterward']
#
# Movie 172 character names:
# ['Cheyenne', 'Harry']
#
# Movie 173 character names:
# ['Willie', 'Cooper', 'Lola', 'Ruby', 'Mountain', 'Boy', '[', '’', 'Paiute', 'Indian', 'Robert', 'Blake', 'Deputy', 'Sheriff', 'Abashed']
#
# Movie 174 character names:
# ['*', 'Peter', 'Haber', 'Martin', 'Beck', 'Mikael', 'Persbrandt', 'Gunvald', 'Larsson', 'Stina', 'Rautelin', 'Lena', 'Klingström', 'Per', 'Morberg', 'Joakim', 'Wersén', 'Rebecka', 'Hemse', 'Inger', 'Michael', 'Nyqvist', 'John', 'Banck', 'Anna', 'Ulrica', 'Ericsson', 'Yvonne', 'Jäder', 'Hüttner', 'Oljelund', 'Lennart', 'Hjulström', 'Gavling', 'Lasse', 'Lindroth']
#
# Movie 175 character names:
# ['Min', 'Soo-Ah', 'Ki-Sub', 'Detective', 'Myung', 'Jin', 'Soo-ah', 'Seul-Gi', 'Jo', 'Kwon', 'Facetime', 'Spoiler', 'Detective/Min', 'Halfway', "'office", 'Cat', 'Mouse']
#
# Movie 176 character names:
# ['Lechock', 'Ryan', 'Barb', 'Cap', 'Mom', 'Willie', 'Dottie', 'Neely', 'Duffy', 'Baby', 'Capt', 'Geech', 'Carib', 'Gold', 'Atmospheric', 'Key', 'West', 'Coast', 'Guard']
#
# Movie 177 character names:
# ['Nanjing', 'Seven', 'International', 'Military', 'Tribunal', 'Far', 'East', 'December', 'Sugamo', 'Prison', 'Tokyo', 'America']
#
# Movie 178 character names:
# ['Jago', 'Othello', 'Dessie', 'Cass', 'Commissioner', 'Roderick', 'Lulu', 'Carver', 'Home', 'Secretary', 'Prime', 'Minister', 'Ben', 'London', 'Metropolitan', 'Police', 'Sinclair', 'John', 'Brabant', 'Michael', 'Billy', 'Coates', 'Alan', 'Coastes']
#
# Movie 179 character names:
# ['Susy', 'Roat', 'Sam', 'Talman', 'Lisa', 'Carlino', 'Gloria', 'Montreal', 'New', 'York', 'City', 'Hendrix', 'Mike', 'Harry', 'Jr.', 'Corlino']
#
# Movie 180 character names:
# ['Devon', 'Governor', 'Majors', 'Cobbs', 'Graham', 'Gloria', 'Louisiana', 'Chip', 'North', 'Carolina', 'Senator', 'Edmonds', 'Vice', 'Presidential', 'Thomas']
#
# Movie 181 character names:
# ['Henriette', 'Louise', 'Chevalier', 'Vaudrey', 'Paris', 'Frochard', 'Praille', 'Danton', 'Mother', 'Royalist', 'Robespierre', 'Forget-not', 'Revolution', 'Forchard', 'Louis', 'XVI', 'Aunt', 'France']
#
# Movie 182 character names:
# ['Vinod', 'Iram', 'Kazan', 'Ruby', 'Colonel', 'Metla', 'Nazer', 'Freddie', 'Morocco', 'ISI', 'Col.', 'Huzefa', 'Agent', "'242", 'Khambatta', 'Rajan', 'New', 'Delhi', 'Abu', 'India', "'Colonel", 'Karachi', 'Afghanistan', 'RAW', 'Major', 'Farah', 'Nawaz', 'Marakkesh', 'David', 'MI6', 'Latvia', 'ID', 'Dasht-E-Margoh', 'Taliban', 'Research', 'Analysis', 'Wing', 'Hassan', 'Russia', 'Moscow', 'Mendes', 'British-Pakistani', 'Jagadishwar', 'LTTE', 'Omar', 'Khayyam', "'Rubaiyyat", 'Chaman', 'Baluchistan', 'Pasha', 'Rubaiyat', 'ISI/Lashkar', 'Jimmy', 'Zeus', 'London', 'Lashkar-e-Toiba', 'Pakistan', 'Lashkar', 'Cape', 'Town']
#
# Movie 183 character names:
# ['Karishma', 'Karan', 'Krakow', 'University', 'Poland', 'Shakti', 'Samanta', 'Aradhana', 'Kati', 'Patang', 'Amar', 'Prem', 'Kashmir', 'Ki', 'Kali']
#
# Movie 184 character names:
# ['Justine', 'Seb', 'Montreal', 'Carmine', 'Sasha', 'Stephen', 'Decker', 'Calgary']
#
# Movie 185 character names:
# []
#
# Movie 186 character names:
# ['Zack', 'Kelly', 'Slater', 'Screech', 'Carla', 'Lisa', 'Freddy', 'Kurt', 'Stardust', 'Las', 'Vegas', 'Hotel', 'Melanie', 'Bronco', 'Bert', 'Diana', 'Stooges', 'Bayside', 'Considine', 'Diamond', 'Banner', 'Katrina', 'Silver', 'Derek', 'Frank', 'Jessie', 'High', 'School', 'Martin', 'Herb', 'Ray', 'San', 'Diego', 'Sheriff', 'Top', 'Strip', 'Restaurant', 'Union', 'Plaza', 'BMW', 'Fremont', 'Street', 'Three', 'Bells', 'Chapel', 'Morris', 'Maid', 'Honor', 'Kapowski', 'Spano', 'Bell', 'Mike', 'Rogers', 'Alex', 'Tabor', 'Richard', 'Belding', 'Carol']
#
# Movie 187 character names:
# ['Billa', 'Dimitri', 'Rao', 'Kotiswara', 'Jasmine', 'Ranjith', '[', 'Abbasi', 'Sameera', 'David', 'Goa', 'Malaysia', 'Sri', 'Lankan', 'Rameswaram', 'Raghubir', 'Sinha', 'Krishna', 'Kumar', 'Rameshwaram', 'Chennai', 'Selvaraj', 'Jagdish', 'Rahman', 'India', 'Russia']
#
# Movie 188 character names:
# ['Khurana', 'Omi', '’', 'Chicken', 'London', 'Punjab', '“', 'UK', 'Darji', 'Harman', 'Jeet', 'Titu', '”', 'Luv', 'Shuv', 'Tey', 'November', 'Khosla', 'Ka', 'Ghosla', 'Dev', 'D']
#
# Movie 189 character names:
# ['Tuesday', 'Faraday', 'Cavinder', 'Sabasha', 'Twyly', 'Mrs.', 'Thessaly', 'Pristy', 'Ray', 'Von', 'Vandervon', 'Sinas', 'Teak', 'Jack', 'Hausenstout', 'Seyton', 'Cupcupboard', 'Sarah', 'Burling', 'Dr', 'Jane', 'Famish', 'Jr.', 'Armbruster', 'Tugdon', 'Lord', 'Partfine', 'Ethelquake', 'Fanmoore', 'Eight', "O'Clock", 'Billy', 'Happy', 'Codburn', 'Vestinhaus', 'Farper', 'Strangler', 'Dr.', 'Van', 'Archie', 'Bax', 'Tremblay']
#
# Movie 190 character names:
# ['Regina', 'Mark', 'Paul', 'Carlos', 'Maria', 'Albert', 'Spain', 'Rua', 'Villalobos']
#
# Movie 191 character names:
# ['Avner', 'Robert', 'Louis', 'Salameh', 'Mossad', 'Israel', 'Carl', 'Hamshari', 'Munich', 'Ephraim', 'Steve', 'Muchasi', 'New', 'York', 'Hans', 'Israeli', 'Paris', 'Cyprus', 'Al', 'Bashir', 'Beirut', 'Kamal', 'IDF', 'CIA', 'City', 'Kaufman', 'Prime', 'Minister', 'Golda', 'Meir', 'Rome', 'Abdel', 'Wael', 'Zwaiter', 'Mahmoud', 'Hussein', 'Muhammad', 'Youssef', 'Adwan', 'Nasser', 'Palestine', 'Liberation', 'Organization', 'Defense', 'Sayeret', 'Matkal', 'Athens', 'PLO', 'Basque', 'Euskadi', 'Ta', 'Askatasuna', 'Red', 'Army', 'Faction', 'African', 'National', 'Congress', 'Middle', 'East', 'Zaiad', 'Ali', 'Hassan', 'Massacre', 'US', 'London', 'Dutch', 'Netherlands', 'Spain', 'Twin', 'Towers']
#
# Movie 192 character names:
# ['Dengler', 'Sharon', 'Jack', 'Erich', 'Manferd', 'Art', 'Collector', 'Eric', 'Dane', 'Holman', 'Museum', 'Bell', 'Terry']
#
# Movie 193 character names:
# ['Mituna', 'Singha', 'Jazz', 'Lam', 'Kanda', 'Kong', 'AIDS']
#
# Movie 194 character names:
# ['Woody', 'Woodpecker']
#
# Movie 195 character names:
# ['Ava', 'Charlie', 'Bradley', 'Betty', 'Gerber', '’', 'Shelby', 'Kasia', '”', 'Six', '“', 'South', 'Asia', 'Europe', 'Speed', 'Dating', "Gerber's…", 'Adriana', 'Anniversary']
#
# Movie 196 character names:
# ['Meen', 'Thai', 'Ting', 'May', 'Royal', 'Police', 'Lieutenant', 'Te', 'Miss', 'Thailand', 'Dr.', 'Charun', 'Fai']
#
# Movie 197 character names:
# ['Judex', 'Expand', 'Favraux', 'Diana', 'Jacqueline']
#
# Movie 198 character names:
# ['Tweety', 'Sylvester', 'Granny', 'Ardent', 'Admirer', 'Thomas', 'Jefferson', 'Hector']
#
# Movie 199 character names:
# ['Butte', 'Morgan', 'Maria', 'Wallace', 'Jack', 'Grant', 'Expand']
#
# Movie 200 character names:
# ['Blue', 'Lee', 'Elinor', '’', 'Harlem', 'New', 'York', 'City', 'Benny', 'Fredi', 'German', 'Alan', 'Gevinson', 'American', 'Film', 'Institute', 'Google']

# %% [markdown]
# Version two of first step: extract character names (ordered)

# %%
# Example movie summaries
summaries = RAW.summaries[['Wiki ID', 'Summary']].iloc[:600]

# Function to extract character names from a given summary
def extract_character_names(summary):
    characters = {}
    sentences = sent_tokenize(summary)
    
    for sentence in sentences:
        words = word_tokenize(sentence)
        tagged_words = pos_tag(words)
        
        for i in range(len(tagged_words) - 1):
            if tagged_words[i][1] == 'NNP':  # Proper noun (assumed to be a character name)
                name = tagged_words[i][0]
                characters[name] = characters.get(name, 0) + 1
    
    sorted_characters = sorted(characters.items(), key=lambda x: x[1], reverse=True)
    return [char[0] for char in sorted_characters]

# Create a dictionary of character names for each movie
sorted_character_names_per_movie = {}

for idx, row in summaries.iterrows():
    wiki_id = row['Wiki ID']
    summary = row['Summary']
    
    names = extract_character_names(summary)
    sorted_character_names_per_movie[wiki_id] = names

print(sorted_character_names_per_movie)
# Out:
# {23890098: ['Shlykov', 'Lyosha'], 31186339: ['Katniss', 'Peeta', 'Rue', 'District', 'Haymitch', 'Cato', 'Crane', 'Clove', 'Capitol', 'Hunger', 'Cornucopia', 'President', 'Snow', 'Thresh', 'Panem', 'Reaping', 'Primrose', 'Everdeen', 'Mellark', 'Abernathy', 'Career', 'Caesar', 'Flickerman', 'Games', 'Glimmer', 'Furious', 'Marvel', 'Seneca', 'Gamemaker'], 20663735: ['Induchoodan', 'Menon', 'Manapally', '[', 'Pavithran', 'Indulekha', 'Justice', 'Nambiar', 'Nair', 'Madhavan', 'Anuradha', 'Poovalli', 'Maranchery', 'Karunakara', 'DYSP', 'Sankaranarayanan', 'Indian', 'Civil', 'Service', 'Sudheeran', 'Saikumar', 'Ramakrishnan', 'Moopil', 'Bharathapuzha', 'Aishwarya', 'Mooppil', 'Kerala', 'Kanaka', 'Chandrabhanu', 'Jayakrishnan', 'Poovally', 'Raman', 'Nandagopal', 'Maarar'], 2231378: ['Kid', 'Charley', 'Moran', 'Brainy', 'Nellie', 'Thursday', 'New', 'Santa', 'York', 'Moose', 'Oxford', 'Christmas', 'Claus', 'Lemon', 'Drop', 'City', 'Florida', 'Eve', 'Year', 'Baxter', 'Home', 'Old', 'Dolls', 'Manhattan', 'Nyack', 'Henry'], 595909: ['Lindy', 'Michael', 'Azaria', 'Chamberlains', 'Adventist', 'Church', 'Chamberlain', 'Outback', 'Seven', 'October', 'Uluru'], 5272176: ['Thomas', 'Baldwin', 'Kate', 'Stevens', 'Alex', 'Crawford', 'Jack', 'Agent', 'President', 'Secret', 'Service', 'Vaughan', 'Steven'], 1952976: ['Dahlia', 'Cecilia', 'Natasha', 'Veeck', 'Kyle', 'Murray', 'Jersey', 'City', 'Roosevelt', 'Island', 'Mr.', 'Hello', 'Kitty', 'Rimsky', 'Flash', 'Weeks'], 24225279: ['Hannah', 'Dominic', 'Miss', 'Lombardo', 'Leader', 'Sing', 'Jewish', 'Brooklyn', 'Christmas', 'Senior', 'Mickey', 'Dept', 'Education'], 2462689: ['Doe', 'John', 'Mitchell', 'Willoughby', 'Norton', 'Christmas', 'Eve', 'Connell', '[', 'City', 'Hall', 'Ann', 'Henry', 'D.B', 'Edward', 'Arnold', 'Colonel', 'Millsville', 'Hanson', 'Jesus', 'Christ', 'Try'], 20532852: ['Woody', 'Buzz', 'Buzzard'], 15401493: ['Lola', 'Bo', 'Nikki', 'Simona', 'Marco', 'Dotty', 'Victor', 'Texas', 'New', 'Mexico', 'Caucasian', 'Nina'], 18188932: ['Milan', 'Goran', 'Lubos', 'Eman', 'Miluska', 'Frantisek'], 2940516: ['Goon', 'Show', 'Spike', 'Milligan'], 1335380: ['Ari', 'Karen', 'Dov', 'Akiva', 'Kitty', 'Dafna', 'Irgun', 'Gan', 'Taha', 'Palestine', 'Arab', 'Exodus', 'Israel', 'Jews', 'Ben', 'Canaan', 'Zionist', 'Jewish', 'Landau', 'David', 'Jerusalem', 'Acre', 'Nurse', 'Katherine', 'Fremont', 'Karaolos', 'Cyprus', 'Hagannah', 'Brigade', 'Army', 'World', 'War', 'Mandate', 'Famagusta', 'Hansen', 'America', 'Sonderkommando', 'Auschwitz', 'Nazis', 'Barak', 'Agency', 'King', 'Hotel', 'Mount', 'Tabor', 'Prison', 'Abu', 'Yesha', 'Mohammad', 'Amin', 'Grand', 'Mufti', 'Arabs', 'Palmach'], 1480747: ['Kid', 'Play', 'Sydney', 'Shelia', 'Bilal', 'Miles', 'Rick', 'Jamal', 'Dean', 'Mr', 'Lee', 'Landreaux', 'Zora', 'Salena', 'Kramer', 'Stab', 'Zilla', 'Pee', 'Wee', 'Professor', 'Sinclair', 'Pop', 'Foreplay', "N'Play", 'ID', 'N', 'Pajama', 'Pee-Wee', 'A', 'Pops'], 24448645: ['Lucy'], 15072401: ['Colby', 'Lowell', 'Alan', '*', 'Lowells', 'Henrietta', 'Fred', 'Janice', 'Gage', 'Prof.', 'Bowen', 'Mr.', 'Phelps', 'Ulrich'], 4018288: ['Chris', 'Debbie', 'Dream', 'Street', 'Trousdale', 'Biggest', 'Fan'], 4596602: ['Gabriel', '’', 'Ashes', 'Valentino', 'Triad', 'Michael', 'Arabella', 'Laundrymen', 'London', 'Mafia', 'Enrico', 'England', 'Darbeaux', 'Chinese', 'Triads', 'West', 'Simone', 'Tarantola', 'Muhammed', 'Nelson', 'France', 'Tarontola', 'Bound'], 15224586: ['Vietnam', 'Tai', 'United', 'Minh', 'Duc', 'Fall', 'Saigon', 'War', 'Tran', 'Gunnery', 'Sgt', 'Jim', 'Lance', 'Addie', 'Thuy', 'Hoa'], 15585766: ['Bluey', 'Milo', 'Peter', 'Australia', 'Linton', 'Kate', 'Donkin', 'Trent', 'English', 'Squatter', 'Carmody', 'War', 'Division', 'Africa', 'Tobruk', 'Sister', 'Mary', 'New', 'Guinea'], 1760737: ['Red', 'Lumpy', 'Set', 'Eben', 'Bikes'], 29062594: ['Catholic'], 29326153: ['Lucius', 'West', 'Point', 'First', 'Battle', 'Bull', 'Run'], 9252321: ['Zachariah', '’', '–', 'African', 'Zulu', 'Johannesburg', 'Marumu', 'Sophiatown', 'Fea ...

# %% [markdown]
# Des fois les listes sont trop grandes peut être couper mais potentiel que certains characters soient pas nommés

# %% [markdown]
# Version one second step: Assign Primary and Secondary role.
#
# Le premier character de la liste est First Role tous les autres figurant dans le liste Secondary Role. Pour ceux ne figurant pas dans la liste: Missed.

# %%
def determine_role(row):
    character_name = row['Character name']
    wiki_id = row['Wiki ID']

    # Check if character_name is a string or NaN
    if isinstance(character_name, str):
        # Get the sorted character names for the current movie using Wiki ID
        characters_for_movie = sorted_character_names_per_movie.get(wiki_id, [])

        # Check if any part of the character name matches any part of the first name in the list
        for name in characters_for_movie:
            if isinstance(name, str) and any(part in name for part in character_name.split()):
                # If the character is the first in the list
                if characters_for_movie.index(name) == 0:
                    return 'First Role'
                else:
                    return 'Secondary Role'

    return 'Missed'

# Apply the determine_role function to create the new 'Role_bis' column
RAW.character_data['Role_bis'] = RAW.character_data.apply(determine_role, axis=1)

# %% [markdown]
# Version two second step: Assign Primary and Secondary role.
#
# Le premier character de la liste est First Role, ceux figurant dans le dernier quart de la liste sont second role. Le reste est missed.
#
# Amélioration à faire: Etablir un threshold supérieur pour les Primary role.

# %%
def determine_role_threshold(row):
    character_name = row['Character name']
    wiki_id = row['Wiki ID']

    # Check if character_name is a string or NaN
    if isinstance(character_name, str):
        # Get the sorted character names for the current movie using Wiki ID
        characters_for_movie = sorted_character_names_per_movie.get(wiki_id, [])

        # Set a threshold for considering characters as secondary roles
        threshold = max(2, len(characters_for_movie) // 4)  # Adjust the threshold as needed

        # Check for the first role (if list is not empty)
        if characters_for_movie and any(part in characters_for_movie[0] for part in character_name.split()):
            return 'First Role'
        else:
            # Check for secondary roles
            for name in characters_for_movie[1:]:  # Start iteration from the second item onwards
                if any(part in name for part in character_name.split()):
                    # If the character is beyond the threshold
                    if characters_for_movie.index(name) >= threshold:
                        return 'Secondary Role'

    return 'Missed'

# Apply the determine_role function to create the new 'Role_bis' column
RAW.character_data['Role_bis'] = RAW.character_data.apply(determine_role_threshold, axis=1)

# %% [markdown]
# Version three second step: Assign Primary and Secondary role.
#
# Le premier character de la liste est First Role, ceux figurant dans le dernier quart de la liste sont second role. Le reste est missed.
#
# Amélioration à faire: Etablir un threshold supérieur pour les Primary role.
#
# Addition par rapport à version two: characters with same family name/surname are differentiated (à vérifier que marche car pas encore testé)

# %%
from collections import Counter

def determine_role_threshold_nuance(row):
    character_name = row['Character name']
    wiki_id = row['Wiki ID']

    # Check if character_name is a string or NaN
    if isinstance(character_name, str):
        # Get the sorted character names for the current movie using Wiki ID
        characters_for_movie = sorted_character_names_per_movie.get(wiki_id, [])

        # Set a threshold for considering characters as secondary roles
        threshold = max(2, len(characters_for_movie) // 4)  # Adjust the threshold as needed

        # Check if there are character names for the movie and character_name
        if characters_for_movie:
            # Extract the family or shared surname from the first item in the list
            first_name = characters_for_movie[0].split()[0]  # Assumes the first item represents a family or surname

            # Create lists of names and surnames for characters in the movie
            names = [name.split()[0] for name in characters_for_movie]
            surnames = [name.split()[-1] for name in characters_for_movie]

            # Count occurrences of main character's name and surname within respective lists
            name_count = Counter(names)[character_name.split()[0]]
            surname_count = Counter(surnames)[character_name.split()[-1]]

            # Check if the main character's name or surname has the highest count within the family or surname group
            if (character_name.split()[0] == first_name and name_count >= surname_count) or \
               (character_name.split()[-1] == first_name and surname_count > name_count):
                return 'First Role'
            else:
                # Check for secondary roles based on the threshold
                for name in characters_for_movie[1:]:  # Start iteration from the second item onwards
                    if any(part in name for part in character_name.split()):
                        # If the character is beyond the threshold
                        if characters_for_movie.index(name) >= threshold:
                            return 'Secondary Role'

    return 'Missed'

# Apply the determine_role function to create the new 'Role_bis' column
RAW.character_data['Role_bis'] = RAW.character_data.apply(determine_role_threshold_nuance, axis=1)
